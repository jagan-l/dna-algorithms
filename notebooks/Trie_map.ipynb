# %% [raw]
# A trie is a tree-shaped data structure used to store strings (or sequences) character by character. Instead of storing whole words as keys in one place (like a dictionary), a trie stores them as paths from the root down to leaves.
#
# Tries are used whenever:
#
# - You care about prefixes.
# - You want predictable lookup time based only on key length.
# - You are matching many patterns at once.
#
# A suffix tree is essentially a compressed trie of all suffixes of a genome.
# Multi-pattern matching algorithms use tries to match many short DNA patterns simultaneously.
#
# Lookup time depends only on string length. If your key has length k, query time is O(k). It does NOT depend on how many keys are stored.
#
# Compare that to:
# - Binary search in sorted list → O(log n)
# - Hash map → O(1) average, but depends on hashing
# - Trie lookup is stable and predictable.
#
# Efficient prefix queries -If you want all words starting with “ACT”, you just walk: root → A → C → T
# And everything below that node is a match. Hash maps cannot do that efficiently without scanning all keys.
#
# Shared prefixes save memory (sometimes):- If many keys share prefixes (like DNA k-mers from similar regions), the trie avoids duplicating those prefixes.

# %%
#Trie implementation of a map.  Associating keys (strings or other sequence type) with values.  Values can be any type
class TrieMap():
    def __init__(self,kvs):
        self.root = {} #So at the beginning, the trie is just: An empty dictionary
        for (k,v) in kvs:
            self.add(k,v)

    def add(self,k,v):
        cur = self.root #We create a pointer called cur.
        for c in k:
            if c not in cur: # for each character in the string
                cur[c] = {} #if not there, make new edge on character c
            cur = cur[c] #move down one level -> Go inside the dictionary under key 'C'.
        cur['value'] = v # at the end of the path, add the value

    def query(self,k):
        """
        Is the key k in the trie? If yes, return its value. If not, return None.
        """
        cur = self.root
        for c in k:
            if c not in cur:
                return None
            cur = cur[c]
        return cur.get('value')

# %%
mp = TrieMap([("hello", "value 1"), ("there", 2), ("the", "value 3")])

# %%
mp.query("hello")
# Out:
# 'value 1'

# %%
mp.query("hello there") # returns None

# %%
mp.query("there")
# Out:
# 2

# %%
mp.query("the")
# Out:
# 'value 3'

# %%
mp.query("ther") # returns None
